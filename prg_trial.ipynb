# %% [markdown]
# ---
#
#
# # プログラミング応用　**（体験版）**
# - 放送大学大学院　情報学プログラム　オンライン科目
#    - 体験版のコード３個です。（1章、2章、8章より）

# %% [markdown]
# ---
# - Google Colab利用の場合、下のコードの実行は、メニューから「ランタイム」→「すべてのセルを実行」で行います。
# - 下のコードを編集する場合には、メニューから「ファイル」→「ドライブにコピーを保存」を選び、Google Drive にファイルを保存してから編集を行います。書き込み可能なファイル（prg_trial.ipynb）として編集できます。
# - デフォルトでは、ファイルは、Google Drive の “Colab Notebooks” ディレクトリの下に保存されます。

# %% [markdown]
# ---
# （第1章の例）文字列を表示するコードです。

# %%
""" p1_1.py """

print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ---
#
# （第2章の例）散布図を描画するコードです。

# %%
""" p5_20.py """

import matplotlib.pyplot as plt
import numpy as np

pt_x = np.random.rand(300)
pt_y = np.random.rand(300)
pt_val = np.random.rand(300)

fig, ax = plt.subplots()
im = ax.scatter(pt_x, pt_y, c=pt_val, cmap='viridis')
plt.colorbar(im)
ax.set_title("title")
ax.set_xlabel("X")
ax.set_ylabel("Y")
plt.grid(True)
plt.show()

# %% [markdown]
# ---
# （第8章の例）グラフ「空手クラブのソーシャルネットワーク」をページランクで評価し、描画するコードです。

# %%
""" p8_15.py """

import matplotlib.pyplot as plt
import networkx as nx

g = nx.karate_club_graph()

pr = nx.pagerank(g)
node_color = list(pr.values())
print(pr)

pos = nx.spring_layout(g, seed=42)
nx.draw_networkx_edges(g, pos=pos)
nx.draw_networkx_nodes(g, pos=pos, node_size=700, node_color=node_color, cmap='viridis')
nx.draw_networkx_labels(g, pos=pos, font_size=15, font_color='white')
plt.show()
# Out:
# {0: 0.08850807396280012, 1: 0.057414840497110056, 2: 0.06276686454603017, 3: 0.03721208153631377, 4: 0.020503977347501652, 5: 0.03381044255357727, 6: 0.03152901134345504, 7: 0.026464618678806107, 8: 0.03338155566846444, 9: 0.009463219565799959, 10: 0.020689016083505596, 11: 0.009785686547904305, 12: 0.011474872305945287, 13: 0.033474187085322404, 14: 0.012941600888556285, 15: 0.01637633262359366, 16: 0.016755401561857987, 17: 0.009677265915396801, 18: 0.009544864590131914, 19: 0.013077518431081969, 20: 0.011224235021037596, 21: 0.01136015256356328, 22: 0.01296059860686279, 23: 0.04114596964602211, 24: 0.01663437445025268, 25: 0.028672962013730707, 26: 0.015240392773380823, 27: 0.027235358397633882, 28: 0.01447852177427162, 29: 0.028271813832825125, 30: 0.02303184425091186, 31: 0.04198548926127872, 32: 0.07592643687005646, 33: 0.09698041880501741}

# %% [markdown]
# ---
# # Python開発環境構築について
# - 本科目では Google Colabの利用を推奨しています。PCへPythonの開発環境を無理にインストールする必要はありません。
# - どうしても、Pythonの開発環境をインストールしたい場合は以下の python.org の情報などが参考になります。
#    - https://docs.python.org/ja/3/
#
# - また、放送大学付属図書館の「主任講師が選ぶ参考文献」 (2025年春頃公開)などの書籍も参考にしてください。
#    - https://lib.ouj.ac.jp/
#
#
# ---
#
# 2024年11月
